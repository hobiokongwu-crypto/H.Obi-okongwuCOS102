# %% [markdown]
# ![Morning routine flowchart.png](attachment:9836f848-940e-439b-a06a-dff12554fe5d.png)

# %% [markdown]
# ![Purchase and exit flowchart.png](attachment:bb092b62-1e97-43a3-898e-286f9a76c1ce.png)
