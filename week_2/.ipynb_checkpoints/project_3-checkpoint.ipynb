# %%
# All the lists for the girls
g_names = ['Evelyn', 'Jessica', 'Somto', 'Edith', 'Liza', 'Madonna', 'Waje', 'Tola', 'Aisha', 'Latifa']
g_age= [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
g_height= [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5]
g_scores= [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]

# All the lists for the boys
b_names= ['Chinedu', 'Liam', 'Wale', 'Gbenga', 'Abiola', 'Kola', 'Kunle', 'George', 'Thomas', 'Wesley']
b_age= [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]
b_height= [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]
b_scores= [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

# Concatenate each list together 
name = g_names + b_names
age = g_age + b_age
height = g_height + b_height
scores = g_scores + b_scores
print(f"{'Name':<12}|{'Age':<5}|{'Height':<8}|{'Score':<5}") # Table header
print("-" * 45) # Demarcation line
for n, a, h, s in zip(name, age, height, scores): # Use a zip loop to handle deal with all students 
    print(f"{n:<12}|{a:<5}|{h:<8}|{s:<5}")
# Out:
# Name        |Age  |Height  |Score
# ---------------------------------------------
# Evelyn      |17   |5.5     |80
# Jessica     |16   |6.0     |85
# Somto       |17   |5.4     |70
# Edith       |18   |5.9     |60
# Liza        |16   |5.6     |76
# Madonna     |18   |5.5     |66
# Waje        |17   |6.1     |87
# Tola        |20   |6.0     |95
# Aisha       |19   |5.7     |50
# Latifa      |17   |5.5     |49
# Chinedu     |19   |5.7     |74
# Liam        |16   |5.9     |87
# Wale        |18   |5.8     |75
# Gbenga      |17   |6.1     |68
# Abiola      |20   |5.9     |66
# Kola        |19   |5.5     |78
# Kunle       |16   |6.1     |87
# George      |18   |5.4     |98
# Thomas      |17   |5.8     |54
# Wesley      |19   |5.7     |60

# %% [markdown]
# ![Student Table Flowchart .png](attachment:4bc0adc0-f74c-458d-a7f9-308b465133dc.png)
